# %%
import requests
from bs4 import BeautifulSoup

# %%
target_url = "https://www.zillow.com/homes/Boston,-MA_rb/"

headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp =  requests.get(target_url, headers=headers)

print(resp.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

l=list()
obj={}
target_url = "https://www.zillow.com/homes/Boston,-MA_rb/"

headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.9","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","Accept-Encoding":"gzip, deflate, br","upgrade-insecure-requests":"1"}

resp = requests.get(target_url, headers=headers).text

soup = BeautifulSoup(resp,'html.parser')

properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})
print(len(properties))

for x in range(0,len(properties)): 
  try:
    obj["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
  except:
    obj["pricing"]=None
  try:
    obj["size"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

  except:
    obj["size"]=None
  try:
    obj["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
  except:
    obj["address"]=None
  try:
    obj["link"]=properties[x].find('a', {'href': re.compile("^https://")}).get('href')
  except:
    obj["link"]=None
  l.append(obj)
  obj={}
#print(l)

    
df = pd.DataFrame(l)
df
# Out:
# 9
#       pricing                                               size  \
# 0    $849,000               4 bds2 ba1,600 sqft - House for sale
# 1    $745,000               2 bds2 ba1,048 sqft - Condo for sale
# 2    $489,000               3 bds1 ba1,206 sqft - Condo for sale
# 3    $369,000                  1 bd1 ba436 sqft - Condo for sale
# 4  $2,900,000  11 bds6 ba5,457 sqft - Multi-family home for sale
# 5  $2,800,000   6 bds6 ba3,714 sqft - Multi-family home for sale
# 6        $300                  0 sqft lot  - Lot / Land for sale
# 7    $599,999               3 bds2 ba1,260 sqft - Condo for sale
# 8    $330,000           3 bds2 ba1,056 sqft - Townhouse for sale
#
#                                         address  \
# 0         137 Lasell St, West Roxbury, MA 02132
# 1            69 Lubec St #302, Boston, MA 02128
# 2         38 Semont Rd #1, Dorchester, MA 02124
# 3    758 E 6th St APT 2, South Boston, MA 02127
# 4             28-30 Mercer St, Boston, MA 02127
# ...

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import pandas as pd
import re
from random import random


PATH = '/Users/ruonan/Downloads/chromedriver.exe'
l=list()
obj={}
target_url = "https://www.zillow.com/homes/Boston,-MA_rb/"
driver=webdriver.Chrome(PATH)

driver.get(target_url)
html = driver.find_element(By.TAG_NAME, 'html')
html.send_keys(Keys.END)
#for i inrange(5):
#    t = 1+2*random()
time.sleep(5)
resp = driver.page_source
driver.close()
soup=BeautifulSoup(resp,'html.parser')
properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})
#print(properties)
for x in range(0,len(properties)): 
  try:
    obj["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
  except:
    obj["pricing"]=None
  try:
    obj["size"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

  except:
    obj["size"]=None
  try:
    obj["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
  except:
    obj["address"]=None
  try:
    obj["link"]=properties[x].find('a', {'href': re.compile("^https://")}).get('href')
  except:
    obj["link"]=None
  l.append(obj)
  obj={}
#print(l)

    
df = pd.DataFrame(l)
df 
df.to_csv('zillow_js_rendering.csv')
# Out:
# /var/folders/c2/p7qqzp3s1vb4x2hqhlhr1rvc0000gp/T/ipykernel_5013/1557665175.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

l=list()
obj={}
target_url = "https://www.zillow.com/homes/Boston,-MA_rb/"

headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.9","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","Accept-Encoding":"gzip, deflate, br","upgrade-insecure-requests":"1"}

resp = requests.get(target_url, headers=headers).text

for page in range(1,15):    
    resp =  requests.get("https://www.zillow.com/homes/for_sale/Brooklyn,-New-York,-NY_rb/{}_p/".format(page), headers=headers).text
    soup = BeautifulSoup(resp,'html.parser')

    properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})
    #print(len(properties))

    for x in range(0,len(properties)): 
      try:
        obj["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
      except:
        obj["pricing"]=None
      try:
        obj["size"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

      except:
        obj["size"]=None
      try:
        obj["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
      except:
        obj["address"]=None
      try:
        obj["link"]=properties[x].find('a', {'href': re.compile("^https://")}).get('href')
      except:
        obj["link"]=None
      l.append(obj)
      obj={}
#print(l)

    
df = pd.DataFrame(l)
df
df.to_csv('Sample_data.csv')
